# %%
# your own linear regression build with python code

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'diabetes.csv')

# %%
df
# Out:
#      patient_number  cholesterol  glucose  hdl_chol chol_hdl_ratio  age  \
# 0                 1          193       77        49            3,9   19
# 1                 2          146       79        41            3,6   19
# 2                 3          217       75        54              4   20
# 3                 4          226       97        70            3,2   20
# 4                 5          164       91        67            2,4   20
# ..              ...          ...      ...       ...            ...  ...
# 385             386          227      105        44            5,2   83
# 386             387          226      279        52            4,3   84
# 387             388          301       90       118            2,6   89
# 388             389          232      184       114              2   91
# 389             390          165       94        69            2,4   92
#
#      gender  height  weight   bmi  systolic_bp  diastolic_bp  waist  hip  \
# ...

# %%
x = df['weight'].values.reshape(-1,1)
y = df['hip'].values.reshape(-1,1)

# %%
x
# Out:
# array([[119],
#        [135],
#        [187],
#        [114],
#        [141],
#        [161],
#        [115],
#        [145],
#        [159],
#        [170],
#        [187],
#        [274],
#        [169],
#        [142],
#        [155],
#        [158],
#        [163],
#        [220],
#        [114],
#        [148],
#        [223],
#        [137],
#        [160],
#        [235],
#        [277],
#        [185],
#        [180],
#        [183],
#        [164],
#        [245],
#        [113],
#        [118],
#        [245],
#        [154],
#        [162],
#        [174],
#        [174],
#        [130],
#        [227],
#        [259],
#        [150],
#        [119],
#        [145],
#        [170],
#        [210],
#        [209],
#        [289],
#        [185],
#        [141],
#        [179],
#        [180],
#        [204],
#        [130],
#        [154],
#        [200],
#        [126],
#        [200],
#        [225],
#        [170],
#        [123],
#        [ 99],
#        [120],
# ...

# %%
y
# Out:
# array([[38],
#        [40],
#        [45],
#        [39],
#        [39],
#        [40],
#        [37],
#        [36],
#        [39],
#        [46],
#        [41],
#        [58],
#        [43],
#        [39],
#        [39],
#        [43],
#        [39],
#        [52],
#        [35],
#        [38],
#        [50],
#        [35],
#        [40],
#        [50],
#        [49],
#        [47],
#        [41],
#        [45],
#        [40],
#        [47],
#        [38],
#        [34],
#        [58],
#        [42],
#        [39],
#        [46],
#        [35],
#        [40],
#        [44],
#        [49],
#        [39],
#        [37],
#        [35],
#        [41],
#        [47],
#        [43],
#        [51],
#        [44],
#        [38],
#        [42],
#        [43],
#        [41],
#        [35],
#        [38],
#        [46],
#        [32],
#        [45],
#        [52],
#        [39],
#        [37],
#        [36],
#        [38],
#        [48],
#        [42],
#        [40],
#        [34],
# ...

# %%
#now build own linearRegresson model with python

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.20)

# %%
class yourmodel:
    
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit(self,xtrain,ytrain):
        num =0
        den = 0
        
        for i in range(xtrain.shape[0]):
            #now calculate m value formula = (xi - xmean) (yi - ymean)
                                                    #-------------------------
                                                     # (xi - xmean)2
                    #first (xi - xmean) - (yi - y mean)
                    
                num = num + ((xtrain[i] - xtrain.mean()) * (ytrain[i] - ytrain.mean()))
                 #first (xi - xmean) - (yi - y mean)
                    
           
                    # send (xi - xmean)2
                    
                den =  den + ((xtrain[i] - xtrain.mean()) * (xtrain[i] - xtrain.mean()))
            
        self.m = num/den
        #now calculate  b
        # b =  y(mean)- m xmean
        
        self.b = ytrain.mean() - (self.m * xtrain.mean())
        
        print("coef",self.m)
        print("intercept",self.b)
            
    def predict(self,xtest):
          # y = mx + b 
        print(xtest)
        return self.m * xtest +self.b
            
        # complete your model now fit and predict tha model

# %%
lr  = yourmodel()

# %%
lr

# %%
#now fit tha model
lr.fit(xtrain,ytrain)
# Out:
# coef [0.11624112]
# intercept [22.4199573]

# %%
#this your m,b values

# %%
# now predict the model

# %%
lr.predict(xtest)
# Out:
# [[127]
#  [180]
#  [145]
#  [251]
#  [142]
#  [215]
#  [204]
#  [174]
#  [198]
#  [192]
#  [290]
#  [159]
#  [181]
#  [183]
#  [141]
#  [186]
#  [147]
#  [262]
#  [158]
#  [167]
#  [217]
#  [136]
#  [200]
#  [183]
#  [123]
#  [182]
#  [125]
#  [154]
#  [191]
#  [190]
#  [186]
#  [189]
#  [169]
#  [169]
#  [223]
#  [162]
#  [140]
#  [181]
#  [205]
#  [200]
#  [156]
#  [187]
#  [167]
#  [118]
#  [169]
#  [145]
#  [135]
#  [144]
#  [144]
#  [175]
#  [189]
#  [139]
#  [ 99]
#  [172]
#  [200]
#  [140]
#  [170]
#  [235]
#  [200]
#  [212]
#  [159]
#  [159]
#  [212]
#  [167]
#  [175]
#  [182]
#  [163]
#  [224]
#  [180]
#  [205]
#  [282]
#  [183]
#  [191]
#  [118]
#  [259]
#  [197]
#  [227]
#  [136]]
# array([[37.18257992],
#        [43.34335944],
#        [39.27492013],
#        [51.59647917],
#        [38.92619677],
#        [47.41179875],
#        [46.13314639],
#        [42.6459127 ],
#        [45.43569965],
#        [44.73825292],
#        [56.12988297],
#        [40.90229586],
# ...

# %%
#now check with compare the sklearn model and your model

# %%
from sklearn.linear_model import LinearRegression

# %%
l = LinearRegression()

# %%
l.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
#now 2 model ,1.is your model,2.sklearn model compare

# %%
lr

# %%
l
# Out:
# LinearRegression()

# %%
#this one your model
lr.predict([xtest[0]])
# Out:
# [array([127], dtype=int64)]
# array([[37.18257992]])

# %%
# this one sklearn model 
l.predict([xtest[0]])
# Out:
# array([[37.18257992]])

# %%
xtest[0]
# Out:
# array([127], dtype=int64)

# %%
ytest[0]
# Out:
# array([38], dtype=int64)

# %%
# 2 model is same prediction

# %%
#m,b value sklearn and your model

# %%
l.coef_
# Out:
# array([[0.11624112]])

# %%
l.intercept_
# Out:
# array([22.4199573])

# %%
lr.fit(xtrain,ytrain)# your model
# Out:
# coef [0.11624112]
# intercept [22.4199573]

# %%
# your model and sklearn model bath are same good work
